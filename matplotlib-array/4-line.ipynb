# %%
import matplotlib.pyplot as plt

# %%
y = [3,8,1,10]
plt.plot(y, linestyle = 'dashed')
plt.show()

# %%
plt.plot(y, color='r')
plt.show()

# %%
x = [6,2,7,11]

plt.plot(y)
plt.plot(x)

plt.show()
